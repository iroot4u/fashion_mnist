# %%
from keras.datasets import fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
# Out:
# /Project/apps/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
import numpy as np
np.random.seed(123)

# %%
x_data = x_test.reshape(x_test.shape[0], 784)

# %%
x_data.shape
# Out:
# (10000, 784)

# %%
from sklearn.decomposition import PCA
import pandas as pd

# %%
pca = PCA(n_components=3)
principalComponents = pca.fit_transform(x_data)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2', 'principal component 3'])

# %%
principalDf.shape
# Out:
# (10000, 3)

# %%
draw_data = principalDf.as_matrix()

# %%
draw_data.shape
# Out:
# (10000, 3)

# %%
label_data = y_test.reshape(10000, 1)
label_data.shape
# Out:
# (10000, 1)

# %%
plot_data = np.concatenate((draw_data, label_data), axis=1)

# %%
idx = np.random.randint(plot_data.shape[0], size=1000)

# %%
# sample_data = plot_data[idx]
sample_data = plot_data
sample_data.shape
# Out:
# (10000, 4)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.colors as clr
from mpl_toolkits.mplot3d import Axes3D
import plotly.plotly as py
import numpy as np

# %%
labels = ['T-shirt/Top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle Boot']

# %%
labels
# Out:
# ['T-shirt/Top',
#  'Trouser',
#  'Pullover',
#  'Dress',
#  'Coat',
#  'Sandal',
#  'Shirt',
#  'Sneaker',
#  'Bag',
#  'Ankle Boot']

# %%
sample_data[:,0].size
# Out:
# 10000

# %%
colors = ['blue', 'green', 'red', 'cyan', 'magenta', 'yellow', 'darkgreen', 'coral', 'indigo', 'lime']
for x in sample_data:
    plt.scatter(x[0], x[1], s=20, c=colors[int(x[3])], alpha=0.8)

fig = plt.gcf()
fig.set_size_inches(15, 10)
plt.show()

# %%
# %matplotlib qt
fig = plt.figure()
# fig.set_size_inches(15, 10)
ax = fig.add_subplot(111, projection='3d')
ax.view_init(30, 30)
for x in sample_data:
    ax.scatter(x[0], x[1], x[2], zdir='z', s=30, c=colors[int(x[3])], depthshade=True)    
plt.show()
# plt.savefig('chart.eps')
# for angle in range(0, 360):
#     canvas.draw()
#     image = np.fromstring(canvas.
# Out:
# ...
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">

# %%
for i in range(10):
    plt.text(0, i*0.1, labels[i], style='normal', bbox={'color': colors[i], 'alpha': 0.7, 'pad': 5})
plt.axis('off')
plt.show()
